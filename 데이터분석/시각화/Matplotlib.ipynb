# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 1s (9,183 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'NanumBarunGothic'

df = pd.read_excel('./시도별 전출입 인구수.xlsx')

df = df.fillna(method = "ffill")

mask = (df['전출지별'] == "서울특별시") & (df['전입지별'] != "서울특별시")
df_seoul = df[mask]
df_seoul.drop(['전출지별'], axis=1, inplace = True)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

sr_gg = df_seoul.loc['경기도']

plt.style.use('ggplot')

# 객체화
ax = plt.figure(figsize = (14, 5))
ax1 = ax.add_subplot(2, 1, 1)
ax2 = ax.add_subplot(2, 1, 2)

# 객체에 직접 설정
ax1.plot(sr_gg, marker = 'o', markersize=10)
ax2.plot(sr_gg, marker='o', markerfacecolor='green', markersize=10, color='olive', linewidth=5, label='서울 -> 경기')

# y축 범위
ax1.set_ylim(50000, 800000)
ax2.set_ylim(50000, 800000)

# x좌표 이름 회전
ax1.set_xticklabels(sr_gg.index, rotation=90)
ax2.set_xticklabels(sr_gg.index, rotation=90)

plt.show()
# Out:
# <ipython-input-5-983a60f62cd7>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.drop(['전출지별'], axis=1, inplace = True)
# <ipython-input-5-983a60f62cd7>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
# <ipython-input-5-983a60f62cd7>:34: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(sr_gg.index, rotation=90)
# <ipython-input-5-983a60f62cd7>:35: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(sr_gg.index, rotation=90)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'NanumBarunGothic'

df = pd.read_excel('./시도별 전출입 인구수.xlsx')

df = df.fillna(method = "ffill")

mask = (df['전출지별'] == "서울특별시") & (df['전입지별'] != "서울특별시")
df_seoul = df[mask]
df_seoul.drop(['전출지별'], axis=1, inplace = True)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

sr_gg = df_seoul.loc['경기도']

plt.style.use('ggplot')

# 객체화
ax = plt.figure(figsize = (14, 5))
ax1 = ax.add_subplot(2, 1, 1)
ax2 = ax.add_subplot(2, 1, 2)

# 객체에 직접 설정
ax1.plot(sr_gg, marker = 'o', markersize=10)
ax2.plot(sr_gg, marker='o', markerfacecolor='green', markersize=10, color='olive', linewidth=5, label='서울 -> 경기')

# y축 범위
ax1.set_ylim(50000, 800000)
ax2.set_ylim(50000, 800000)

# x좌표 이름 회전
ax1.set_xticklabels(sr_gg.index, rotation=90)
ax2.set_xticklabels(sr_gg.index, rotation=90)

# 차트 제목
ax1.set_title('서울 -> 경기 이동 인구수')
ax1.set_title('서울 -> 경기 이동 인구수')

# 축 제목
ax1.set_xlabel('기간')
ax1.set_ylabel('이동 인구수')

ax2.set_xlabel('기간')
ax2.set_ylabel('이동 인구수')

# 간견 조정
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-7-1d458d4c1fc3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.drop(['전출지별'], axis=1, inplace = True)
# <ipython-input-7-1d458d4c1fc3>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
# <ipython-input-7-1d458d4c1fc3>:34: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(sr_gg.index, rotation=90)
# <ipython-input-7-1d458d4c1fc3>:35: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(sr_gg.index, rotation=90)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'NanumBarunGothic'

df = pd.read_excel('./시도별 전출입 인구수.xlsx')

df = df.fillna(method = "ffill")

mask = (df['전출지별'] == "서울특별시") & (df['전입지별'] != "서울특별시")
df_seoul = df[mask]
df_seoul.drop(['전출지별'], axis=1, inplace = True)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

# 충청북도, 전라남도, 경상북도 (1970 ~ 2017)
col_year = list(map(str, range(1970, 2018)))

sr_gg1 = df_seoul.loc[['충청북도', '전라남도', '경상북도'], col_year]

plt.style.use('ggplot')

# 객체화
ax = plt.figure(figsize = (20, 5))
ax1 = ax.add_subplot(1, 1, 1)

# 객체에 직접 설정
ax1.plot(col_year, sr_gg1.loc['충청북도', :], marker='o', markerfacecolor='green', markersize=10, color='olive', linewidth=2, label='서울 -> 충북')
ax1.plot(col_year, sr_gg1.loc['전라남도', :], marker='o', markerfacecolor='blue', markersize=10, color='skyblue', linewidth=2, label='서울 -> 전남')
ax1.plot(col_year, sr_gg1.loc['경상북도', :], marker='o', markerfacecolor='magenta', markersize=10, color='red', linewidth=2, label='서울 -> 경북')

ax1.legend('best')

# x좌표 이름 회전
ax1.set_xticklabels(col_year, rotation=90)


# 차트 제목
ax1.set_title('서울 -> 충북, 전남, 경북 이동 인구수')


# 축 제목
ax1.set_xlabel('기간', size=10)
ax1.set_ylabel('이동 인구수', size=10)

# 눈금 글씨 크기 조정
ax1.tick_params(axis='x', labelsize=10)
ax1.tick_params(axis='y', labelsize=10)


plt.show()
# Out:
# <ipython-input-17-14cf99c2f5e6>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.drop(['전출지별'], axis=1, inplace = True)
# <ipython-input-17-14cf99c2f5e6>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
# <ipython-input-17-14cf99c2f5e6>:35: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(col_year, rotation=90)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'NanumBarunGothic'

df = pd.read_excel('./시도별 전출입 인구수.xlsx')

df = df.fillna(method = "ffill")

mask = (df['전출지별'] == "서울특별시") & (df['전입지별'] != "서울특별시")
df_seoul = df[mask]
df_seoul.drop(['전출지별'], axis=1, inplace = True)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

# 충청북도, 전라남도, 경상북도, 강원도 (1970 ~ 2017)
col_year = list(map(str, range(1970, 2018)))

sr_gg1 = df_seoul.loc[['충청북도', '전라남도', '경상북도', '강원도'], col_year]

plt.style.use('ggplot')

# 객체화
ax = plt.figure(figsize = (20, 10))
ax1 = ax.add_subplot(2, 2, 1)
ax2 = ax.add_subplot(2, 2, 2)
ax3 = ax.add_subplot(2, 2, 3)
ax4 = ax.add_subplot(2, 2, 4)


# 객체에 직접 설정
ax1.plot(col_year, sr_gg1.loc['충청북도', :], marker='o', markerfacecolor='green', markersize=10, color='olive', linewidth=2, label='서울 -> 충북')
ax2.plot(col_year, sr_gg1.loc['전라남도', :], marker='o', markerfacecolor='blue', markersize=10, color='skyblue', linewidth=2, label='서울 -> 전남')
ax3.plot(col_year, sr_gg1.loc['경상북도', :], marker='o', markerfacecolor='magenta', markersize=10, color='red', linewidth=2, label='서울 -> 경북')
ax4.plot(col_year, sr_gg1.loc['강원도', :], marker='o', markerfacecolor='orange', markersize=10, color='yellow', linewidth=2, label='서울 -> 강원')

ax1.legend('best')
ax2.legend('best')
ax3.legend('best')
ax4.legend('best')


# x좌표 이름 회전
ax1.set_xticklabels(col_year, rotation=90)
ax2.set_xticklabels(col_year, rotation=90)
ax3.set_xticklabels(col_year, rotation=90)
ax4.set_xticklabels(col_year, rotation=90)


# 차트 제목
ax1.set_title('서울 -> 충북 이동 인구수')
ax2.set_title('서울 -> 전남 이동 인구수')
ax3.set_title('서울 -> 경북 이동 인구수')
ax4.set_title('서울 -> 강원 이동 인구수')


# 축 제목
ax1.set_xlabel('기간', size=10)
ax1.set_ylabel('이동 인구수', size=10)
ax2.set_xlabel('기간', size=10)
ax2.set_ylabel('이동 인구수', size=10)
ax3.set_xlabel('기간', size=10)
ax3.set_ylabel('이동 인구수', size=10)
ax4.set_xlabel('기간', size=10)
ax4.set_ylabel('이동 인구수', size=10)

# 눈금 글씨 크기 조정
ax1.tick_params(axis='x', labelsize=10)
ax1.tick_params(axis='y', labelsize=10)
ax2.tick_params(axis='x', labelsize=10)
ax2.tick_params(axis='y', labelsize=10)
ax3.tick_params(axis='x', labelsize=10)
ax3.tick_params(axis='y', labelsize=10)
ax4.tick_params(axis='x', labelsize=10)
ax4.tick_params(axis='y', labelsize=10)

# 간견 조정
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-19-ca003eec0697>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.drop(['전출지별'], axis=1, inplace = True)
# <ipython-input-19-ca003eec0697>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
# <ipython-input-19-ca003eec0697>:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(col_year, rotation=90)
# <ipython-input-19-ca003eec0697>:45: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(col_year, rotation=90)
# ...

# %%
# color picker : 생삭 선택 도구

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'NanumBarunGothic'

df = pd.read_excel('./시도별 전출입 인구수.xlsx')

df = df.fillna(method = "ffill")

mask = (df['전출지별'] == "서울특별시") & (df['전입지별'] != "서울특별시")
df_seoul = df[mask]
df_seoul.drop(['전출지별'], axis=1, inplace = True)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

# 충청북도, 전라남도, 경상북도, 강원도 (1970 ~ 2017)
col_year = list(map(str, range(1970, 2018)))

sr_gg1 = df_seoul.loc[['충청북도', '전라남도', '경상북도', '강원도'], col_year]
sr_gg1 = sr_gg1.T

sr_gg1.plot(kind='area', stacked=False, alpha=0.2, figsize=(20, 10)) # stacked : 누적, alpha : 투명도

plt.title('서울 -> 타도시 이동 인구수')
plt.xlabel('기간')
plt.ylabel('이동 인구수')

plt.show()
# Out:
# <ipython-input-24-e34e649f01e0>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.drop(['전출지별'], axis=1, inplace = True)
# <ipython-input-24-e34e649f01e0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'NanumBarunGothic'

df = pd.read_excel('./시도별 전출입 인구수.xlsx')

df = df.fillna(method = "ffill")

mask = (df['전출지별'] == "서울특별시") & (df['전입지별'] != "서울특별시")
df_seoul = df[mask]
df_seoul.drop(['전출지별'], axis=1, inplace = True)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

# 충청북도, 전라남도, 경상북도, 강원도 (1970 ~ 2017)
col_year = list(map(str, range(1970, 2018)))

sr_gg1 = df_seoul.loc[['충청북도', '전라남도', '경상북도', '강원도'], col_year]
sr_gg1 = sr_gg1.T

sr_gg1.plot(kind='area', stacked=True, alpha=0.2, figsize=(20, 10)) # stacked : 누적

plt.title('서울 -> 타도시 누적 이동 인구수')
plt.xlabel('기간')
plt.ylabel('이동 인구수')

plt.show()
# Out:
# <ipython-input-26-3f2b2e0c5ce5>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.drop(['전출지별'], axis=1, inplace = True)
# <ipython-input-26-3f2b2e0c5ce5>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'NanumBarunGothic'

df = pd.read_excel('./시도별 전출입 인구수.xlsx')

df = df.fillna(method = "ffill")

mask = (df['전출지별'] == "서울특별시") & (df['전입지별'] != "서울특별시")
df_seoul = df[mask]
df_seoul.drop(['전출지별'], axis=1, inplace = True)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

# 충청북도, 전라남도, 경상북도, 강원도 (1970 ~ 2017)
col_year = list(map(str, range(2000, 2018)))

sr_gg1 = df_seoul.loc[['충청북도', '전라남도', '경상북도', '강원도'], col_year]
sr_gg1 = sr_gg1.T

# 막대 그래프
sr_gg1.plot(kind='bar', figsize=(20, 10), width = 0.7,
            color = ['orange', 'green', 'blue', 'red'])

plt.title('서울 -> 타도시 이동 인구수')
plt.xlabel('기간')
plt.ylabel('이동 인구수')

plt.show()
# Out:
# <ipython-input-27-f907d2e5573b>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.drop(['전출지별'], axis=1, inplace = True)
# <ipython-input-27-f907d2e5573b>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'NanumBarunGothic'

df = pd.read_excel('./시도별 전출입 인구수.xlsx')

df = df.fillna(method = "ffill")

mask = (df['전출지별'] == "서울특별시") & (df['전입지별'] != "서울특별시")
df_seoul = df[mask]
df_seoul.drop(['전출지별'], axis=1, inplace = True)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

# 충청북도, 전라남도, 경상북도, 강원도 (1970 ~ 2017)
col_year = list(map(str, range(2000, 2018)))

sr_gg1 = df_seoul.loc[['충청북도', '전라남도', '경상북도', '강원도'], col_year]
sr_gg1['합계'] = sr_gg1.sum(axis= 1)

# 정렬
sr_gg_total = sr_gg1[['합계']].sort_values(by='합계', ascending=True) 

# 수평 막대 그래프
sr_gg_total.plot(kind='barh', figsize=(20, 10), width = 0.7)

plt.title('서울 -> 타도시 이동 인구수')
plt.xlabel('기간')
plt.ylabel('이동 인구수')

plt.show()
# Out:
# <ipython-input-30-c46dd7696450>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.drop(['전출지별'], axis=1, inplace = True)
# <ipython-input-30-c46dd7696450>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('classic')

df = pd.read_excel('auto-mpg.xlsx', header = None)
df.columns = ['mpg', 'cylinders', 'displacement', 'horsepower',
              'weight', 'acceleration', 'model_year', 'origin', 'name']

df['mpg'].plot(kind='hist', bins =10, figsize = (10, 5))

plt.title('Histogram')
plt.xlabel('mpg')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('default')

df = pd.read_excel('auto-mpg.xlsx', header = None)
df.columns = ['mpg', 'cylinders', 'displacement', 'horsepower',
              'weight', 'acceleration', 'model_year', 'origin', 'name']

cylinder_size = df.cylinders / df.cylinders.max() * 300

df.plot(x='mpg', y= 'weight', kind='scatter', color='coral', s=cylinder_size, figsize=(10, 5), alpha=0.3)

plt.title('Scatter Plot - mpg vs weight')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('default')

df = pd.read_excel('auto-mpg.xlsx', header = None)
df.columns = ['mpg', 'cylinders', 'displacement', 'horsepower',
              'weight', 'acceleration', 'model_year', 'origin', 'name']

cylinder_size = df.cylinders / df.cylinders.max() * 300

df.plot(x='mpg', y= 'weight', kind='scatter', color=cylinder_size, cmap='viridis', s=10, figsize=(10, 5), alpha=0.3)

plt.title('Scatter Plot - mpg vs weight')

plt.show()
# Out:
# <ipython-input-40-6e03ce8359a4>:12: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   df.plot(x='mpg', y= 'weight', kind='scatter', color=cylinder_size, cmap='viridis', s=10, figsize=(10, 5), alpha=0.3)

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

# read_csv() 함수로 df 생성
df = pd.read_excel('auto-mpg.xlsx', header=None)

plt.style.use('default')   # 스타일 서식 지정

# 열 이름을 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']

# 데이터 개수 카운트를 위해 값 1을 가진 열을 추가
df['count'] = 1
df_origin = df.groupby('origin').sum()   # origin 열을 기준으로 그룹화, 합계 연산
print(df_origin.head())                  # 그룹 연산 결과 출력

# 제조국가(origin) 값을 실제 지역명으로 변경
df_origin.index = ['USA', 'EU', 'JAPAN']

# 제조국가(origin) 열에 대한 파이 차트 그리기 – count 열 데이터 사용
df_origin['count'].plot(kind='pie', 
                     figsize=(7, 5),
                     autopct='%0.1f%%',   # 퍼센트 % 표시
                     startangle=10,       # 파이 조각을 나누는 시작점(각도 표시)
                     colors=['chocolate', 'bisque', 'cadetblue']    # 색상 리스트
                     )

plt.title('Model Origin', size=20)
plt.axis('equal')    # 파이 차트의 비율을 같게 (원에 가깝게) 조정
plt.legend(labels=df_origin.index, loc='upper right')   # 범례 표시
plt.show()
# Out:
# <ipython-input-41-92e4eb1348f9>:16: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_origin = df.groupby('origin').sum()   # origin 열을 기준으로 그룹화, 합계 연산
#            mpg  cylinders  displacement  weight  acceleration  model year  \
# origin
# 1       5000.8       1556       61229.5  837121        3743.4       18827
# 2       1952.4        291        7640.0  169631        1175.1        5307
# 3       2405.6        324        8114.0  175477        1277.6        6118
#
#         count
# origin
# 1         249
# 2          70
# 3          79
